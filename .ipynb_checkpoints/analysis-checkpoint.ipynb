# %% [markdown]
# ## TO DO
# 1) clean data
#
#     keep blanks for supplement video type
#     latest book mark is anything but 'latest viewing'
#     convert duration column
#
# 2) new columns
#
#     add, year, month, day of the week columns, hour column
#     differentiate series vs movie using semi colon
#     add colum for if there is a series which season

# %%
#packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

#some basic functions
def print_shape(dataframe,name):
    #prints dataframe shape and name if entered
    print(name+" has: {} rows and {} columns".format(dataframe.shape[0],dataframe.shape[1]))

# %%
#import data
viewing_activity_df = pd.read_csv('data/ViewingActivity.csv',parse_dates = ['Start Time'])
billing_history_df = pd.read_csv('data/BillingHistory.csv',parse_dates=['Transaction Date'])

#clean up viewing history data
viewing_activity_df = viewing_activity_df[viewing_activity_df['Latest Bookmark']!='Not latest view']
viewing_activity_df = viewing_activity_df[viewing_activity_df['Supplemental Video Type'].isnull()]
viewing_activity_df['Duration'] = pd.to_timedelta(viewing_activity_df['Duration'],unit='hours').dt.total_seconds()/3600


print_shape(viewing_activity_df,'Viewing Activity')
viewing_activity_df.head()
# Out:
# Viewing Activity has: 9105 rows and 10 columns
# Billing History has: 97 rows and 15 columns
# Viewing Activity has: 5572 rows and 10 columns
#    Profile Name          Start Time  Duration Attributes  \
# 0          Brad 2020-07-11 02:51:12  1.927222        NaN
# 4          Brad 2020-07-11 00:38:45  0.986667        NaN
# 7          Brad 2020-07-10 02:47:20  0.095278        NaN
# 13         Brad 2020-07-09 02:33:00  0.725278        NaN
# 15         Brad 2020-07-08 23:21:31  0.706389        NaN
#
#                                                 Title Supplemental Video Type  \
# 0                            The Silence of the Lambs                     NaN
# 4                                The Devil's Advocate                     NaN
# 7            Hannibal: Season 3: Contorno (Episode 5)                     NaN
# 13  Abstract: The Art of Design: Season 2: Jonatha...                     NaN
# 15          Hannibal: Season 3: Aperitivo (Episode 4)                     NaN
#
#                            Device Type  Bookmark Latest Bookmark  \
# 0   Vizio MG244 FXCN SX7 CAST Smart TV  01:55:38        01:55:38
# 4   Vizio MG244 FXCN SX7 CAST Smart TV  02:18:09        02:18:09
# 7   Vizio MG244 FXCN SX7 CAST Smart TV  00:35:09        00:35:09
# 13  Vizio MG244 FXCN SX7 CAST Smart TV  00:43:31        00:43:31
# 15  Vizio MG244 FXCN SX7 CAST Smart TV  00:42:43        00:42:43
#
#                Country
# 0   US (United States)
# 4   US (United States)
# 7   US (United States)
# 13  US (United States)
# 15  US (United States)
