# %% [markdown]
# ## TO DO
# 1) clean data
#
#     keep blanks for supplement video type - done
#     latest book mark is anything but 'latest viewing' - done
#     convert duration column - done
#
# 2) new columns
#
#     add, year, month, day of the week columns, hour column
#     differentiate series vs movie using semi colon
#     add colum for if there is a series which season

# %%
#packages
import re
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.options.display.float_format = '{:,.2f}'.format

#some basic functions
def print_shape(dataframe,name):
    #prints dataframe shape and name, name must be in quotes
    # example print(dataframe,'my dataframe')
    print(name+" has: {} rows and {} columns".format(dataframe.shape[0],dataframe.shape[1]))
    

#some less basic functions
def movie_series_parser(x):
    #counts how many semicolons occour, if 1 or zero, assume a movie, if two or more assume a series
    #determines if text is a movie or series by looking to see if the word "Season" or "Part" after a semicolon
    #if it does, a new column will be created called "Season" in the dataframe and that text will be entered there
    #the rest of the function will then delete everthing after the word inclusive of ": Season" or ": Part"
    Movie_or_series = ""
    Season = ""
    Title_of_production = ""
    
    if x.count(":") <2:
        Movie_or_series = 'Movie'
        Title_of_production = x
        return Movie_or_series, Title_of_production, Season
    else:
        Movie_or_series = 'Series'
        try:
            Season_search = re.search(r"(: Season \d)|(: Part \d)",x)
            Season = Season_search.group(1)[2:]
        except:
            Season = 'None'        
        try:    
            Title_search = re.sub(r'(: Season .*)|(: Part .*)','',x)
            Title_of_production = Title_search
        except:
            Title_of_production = x
   
        
        return Movie_or_series, Title_of_production, Season

    
def virality(df):
    '''
    determines how viral a show was for me. average hours between each episode, std dev
    median, 
    '''
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#import data
viewing_activity_df = pd.read_csv('data/ViewingActivity.csv',parse_dates = ['Start Time'])
billing_history_df = pd.read_csv('data/BillingHistory.csv',parse_dates=['Transaction Date'])

#clean up viewing history data
#latest view is duplicate data and supplemental video are netflix ads
#convert duration to a floating numbers
viewing_activity_df = viewing_activity_df[viewing_activity_df['Latest Bookmark']!='Not latest view']
viewing_activity_df = viewing_activity_df[viewing_activity_df['Supplemental Video Type'].isnull()].reset_index(drop=True)
viewing_activity_df['Duration_floating_hours'] = pd.to_timedelta(viewing_activity_df['Duration'],unit='hours').dt.total_seconds()/3600
#add new columns, year, month, hour, weekday, add if movie or series, if series which season
viewing_activity_df['Year'] = viewing_activity_df['Start Time'].dt.year
viewing_activity_df['Month'] = viewing_activity_df['Start Time'].dt.month
viewing_activity_df['Hour'] = viewing_activity_df['Start Time'].dt.hour
viewing_activity_df['Weekday'] = viewing_activity_df['Start Time'].dt.dayofweek
weekday_dict = {0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5:'Friday',6:'Saturday'}
viewing_activity_df["Weekday"].replace(weekday_dict, inplace=True)
#apply movie parser function to determine if this is a movie, series and what season if series
viewing_activity_df['Movie_or_series'], viewing_activity_df['Title_of_production'], viewing_activity_df['Season'] = zip(*viewing_activity_df['Title'].apply(movie_series_parser))
print_shape(viewing_activity_df,'Viewing Activity')
# Out:
# Viewing Activity has: 5572 rows and 18 columns

# %%
#some plots ugh way more than some plots now



#need some colors
Netflix_red = '#E50914'
Netflix_black = '#333333'
#make yearly sum of viewing hours by movie or series and convert that to percentage of time
yearly_hours = viewing_activity_df.groupby(['Year','Movie_or_series']).sum().reset_index()
yearly_hours_for_plotting = yearly_hours.pivot(index='Year',columns='Movie_or_series',values='Duration_floating_hours').reset_index()
yearly_hours_for_plotting['Movie_pct'] = yearly_hours_for_plotting['Movie']/ (yearly_hours_for_plotting['Movie']+yearly_hours_for_plotting['Series'])
yearly_hours_for_plotting['Series_pct'] = 1-yearly_hours_for_plotting['Movie_pct']


#plot the data
font = {'family' : 'Arial Rounded MT Bold',
        'weight' : 'normal',
        'size'   : 14}

plt.rc('font', **font)

fig, ax = plt.subplots(figsize=(12,8))
movies = ax.bar(yearly_hours_for_plotting['Year'],yearly_hours_for_plotting['Movie_pct']*100,color = Netflix_black,label='Movies')
series = ax.bar(yearly_hours_for_plotting['Year'],yearly_hours_for_plotting['Series_pct']*100,color=Netflix_red,bottom=yearly_hours_for_plotting['Movie_pct']*100,label='Series')
ax.legend()

#needed two of these auto labels to get numbers to show on stacked plots
def autolabel_1(rects,auto_height=True):
    """Attach a text label above each bar in *rects*, displaying its height."""    
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, -20),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',color='w')
def autolabel_2(rects,auto_height=True):
    """Attach a text label above each bar in *rects*, displaying its height."""    
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, 100-height),
                    xytext=(0, 10),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',color='black')
autolabel_1(movies)
autolabel_2(series)
plt.xlabel('Year')
ax.set_yticklabels([])
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelbottom=False)
plt.title('Yearly: Movies vs Series',fontsize=24)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
fig.savefig('images/yearly_movies_series.png',dpi=500)
plt.show()

# %%
#need to make some other aggregations daily and hourly
daily_hours = viewing_activity_df.resample('D',on='Start Time').sum().reset_index()
daily_hours['Weekday'] = daily_hours['Start Time'].dt.dayofweek
daily_hours["Weekday"].replace(weekday_dict, inplace=True)
average_weekly_hrs = daily_hours.groupby('Weekday').mean().reset_index()
average_weekly_hrs = average_weekly_hrs.reindex([3,1,5,6,4,0,2]).reset_index(drop=True)


hourly_hours = viewing_activity_df.resample('h',on='Start Time').sum().reset_index()


#make a radar chart on average hours per day of the week
labels = average_weekly_hrs['Weekday'].tolist()
values = average_weekly_hrs['Duration_floating_hours'].tolist()
num_vars = len(average_weekly_hrs)

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values += values[:1]
angles += angles[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
# Draw the outline of our data.
ax.plot(angles, values, color=Netflix_red, linewidth=2,marker='o')
# Fill it in.
ax.fill(angles, values, color=Netflix_red, alpha=0.25)

# Fix axis to go in the right order and start at 12 o'clock.
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# Draw axis lines for each angle and label.
ax.set_thetagrids(np.degrees(angles), labels)
ax.set_rgrids([.5, 1, 1.5, 2])
# Go through labels and adjust alignment based on where
# it is in the circle.
for label, angle in zip(ax.get_xticklabels(), angles):
  if angle in (0, np.pi):
    label.set_horizontalalignment('center')
  elif 0 < angle < np.pi:
    label.set_horizontalalignment('left')
  else:
    label.set_horizontalalignment('right')
ax.set_title('Daily hourly average by day of the week', y=1.08)

fig.savefig('images/weekly_average.png',dpi=500)
plt.show()

# %%
#make a dataframe showing mean and 95% confidence interval
hourly_hours['Weekday'] = hourly_hours['Start Time'].dt.dayofweek
weekday_dict = {0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5:'Friday',6:'Saturday'}
weekday_end_dict = {0:'Weekend',1:'Weekday',2:'Weekday',3:'Weekday',4:'Weekday',5:'Weekday',6:'Weekend'}
hourly_hours['Weekday'].replace(weekday_end_dict, inplace=True)

hourly_hours['Hour'] = hourly_hours['Start Time'].dt.hour

hrs_grouped_df = hourly_hours.groupby(['Weekday','Hour'])['Duration_floating_hours'].agg(['mean', 'count', 'std'])

ci95_hi = []
ci95_lo = []

for i in hrs_grouped_df.index:
    m, c, s = hrs_grouped_df.loc[i]
    ci95_hi.append(m + 2.576*s/math.sqrt(c))
    ci95_lo.append(m - 2.576*s/math.sqrt(c))

hrs_grouped_df['ci99_hi'] = ci95_hi
hrs_grouped_df['ci99_lo'] = ci95_lo
hrs_grouped_df = hrs_grouped_df.reset_index()


weekday_avg_df = hrs_grouped_df[hrs_grouped_df['Weekday']=='Weekday']
weekend_avg_df = hrs_grouped_df[hrs_grouped_df['Weekday']=='Weekend']

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(weekday_avg_df['Hour'],weekday_avg_df['mean'],color='#6C09E5',label='Weekday hourly average')
ax.fill_between(weekday_avg_df['Hour'],weekday_avg_df['ci99_lo'],weekday_avg_df['ci99_hi'],alpha=.25,color='#6C09E5')

ax.plot(weekend_avg_df['Hour'],weekend_avg_df['mean'],color='#E50914',label='Weekend hourly average')
ax.fill_between(weekend_avg_df['Hour'],weekend_avg_df['ci99_lo'],weekend_avg_df['ci99_hi'],alpha=.25,color='#E50914')
plt.grid(True)
plt.xticks(np.arange(min(weekend_avg_df['Hour']), max(weekend_avg_df['Hour'])+1, 1.0))
plt.legend(loc='upper left')
plt.ylabel('Hours')
plt.xlabel('Hour of the day')
plt.title('Resampled Hour Averages: Weekday vs Weekend with 99% C.I.')
fig.savefig('images/daily_average.png',dpi=500)
plt.show()

# %%
#create bar chart of most watched shows
others_shows_list = ['Criminal Minds','Bones','Inborn Pair','Meteor Garden','Once Upon a Time','CSI: Miami']

titles_hourly_df = viewing_activity_df.groupby(['Title_of_production']).sum().reset_index().sort_values(by=['Duration_floating_hours'],ascending=False)
titles_hourly_df = titles_hourly_df[~titles_hourly_df['Title_of_production'].isin(others_shows_list)]

fig, ax = plt.subplots(figsize=(16,8))
by_production = ax.bar(titles_hourly_df['Title_of_production'].head(15),titles_hourly_df['Duration_floating_hours'].head(15),color=Netflix_red)
autolabel_1(by_production)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
ax.set_yticklabels([])
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelbottom=False)
plt.title('Top Shows (hrs)',fontsize=24)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
fig.savefig('images/top_shows.png',dpi=500,bbox_inches='tight')
plt.show()

# %%
#heat map of viewing habits - sum
year = 2020
year_df = viewing_activity_df[viewing_activity_df['Year']==year]
overall_map_df = pd.pivot_table(viewing_activity_df,values='Duration_floating_hours',index=['Hour'],columns=['Weekday'],aggfunc=np.sum)
overall_map_df = overall_map_df[['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']]
overall_map_array = overall_map_df.to_numpy()

fig, ax = plt.subplots(figsize=(5,12))
ax = sns.heatmap(overall_map_df,cmap='YlOrRd')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
plt.title('Overall Heat Map (Tot. hrs)')
plt.savefig('images/overall_heat.png',dpi=500,bbox_inches='tight')
plt.show()

# %%
#heat map of viewing habits - sum
year = 2018
year_df = viewing_activity_df[viewing_activity_df['Year']==year]
overall_map_df = pd.pivot_table(year_df,values='Duration_floating_hours',index=['Hour'],columns=['Weekday'],aggfunc=np.sum)
overall_map_df = overall_map_df[['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']]
overall_map_array = overall_map_df.to_numpy()

fig, ax = plt.subplots(figsize=(5,12))
ax = sns.heatmap(overall_map_df,cmap='YlOrRd')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
plt.title('2018 Heat Map (Tot. hrs)')
plt.savefig('images/2018_heat.png',dpi=500,bbox_inches='tight')
plt.show()

# %%
#basic yearly hours
yearly_hours_2 = viewing_activity_df.groupby(['Year']).sum().reset_index()
yearly_hours_2['Cumulative'] = yearly_hours_2['Duration_floating_hours'].cumsum()

fig, ax1 = plt.subplots(figsize=(12,8))
year= ax1.bar(yearly_hours_2['Year'],yearly_hours_2['Duration_floating_hours'],color = Netflix_red,label='Hrs')

ax1.set_ylabel('Hours',color=Netflix_red)
ax1.tick_params(axis='y',labelcolor=Netflix_red)
ax1.set_xlabel('Year')
ax2 = ax1.twinx()

cumulative = ax2.plot(yearly_hours_2['Year'],yearly_hours_2['Cumulative'],color=Netflix_black,label='Cumulative',linewidth=10)
ax2.set_ylabel('Cumulative Hours',color=Netflix_black)

plt.title('Yearly',fontsize=24)
fig.tight_layout() 
plt.savefig('images/year_to_year.png',dpi=500,bbox_inches='tight')
plt.show()

# %%
from scipy.misc import imread
fig, ax = plt.subplots(figsize=(16,8))

'''
original
'''
# def image_plot(heights, images, spacing=0):
#     # Iterate through images and data, autoscaling the width to
#     # the aspect ratio of the image
#     for i, (height, img) in enumerate(zip(heights, images)):
#         AR = img.shape[1] / img.shape[0]
#         width = height * AR
#         left = width*i + spacing*i
#         right = left + width
#         plt.imshow(img, extent=[left, right, 0, height])
#     # Set x,y limits on plot window
#     plt.xlim(0, right)
#     plt.ylim(0, max(heights)*1.1)

def image_plot(heights, images, spacing=0):
    # Iterate through images and data, autoscaling the width to
    # the aspect ratio of the image
    for i, (height, img) in enumerate(zip(heights, images)):
        AR = img.shape[1] / img.shape[0]
        width = 10
        left = width*i + spacing*i
        right = left + width
        plt.imshow(img, extent=[left, right, 0, height])
    # Set x,y limits on plot window
    plt.xlim(0, right)
    plt.ylim(0, max(heights)*1.1)



# Read in flag images
x_files = imread('images/x_files.jpeg')
mother = imread('images/met_mother.jpeg')


# Make up some data about each country
x_files_data = 83.97
mother_data = 73.03


data = [x_files_data,mother_data]
flags = [x_files,mother]

image_plot(data, flags, spacing=2)
plt.title('test')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
from IPython.core.pylabtools import figsize

dly_hrs_all = viewing_activity_df.resample('D',on='Start Time').sum().reset_index()
dly_hrs = dly_hrs_all[dly_hrs_all['Start Time'].dt.year >= 2020]
dly_hrs['day'] = np.arange(len(dly_hrs))+1
n_data_days = len(dly_hrs)
dly_hrs_array= dly_hrs['Duration_floating_hours'].to_numpy()

figsize(12.5, 3.5)
plt.bar(dly_hrs['day'], dly_hrs['Duration_floating_hours'], color="#348ABD")
plt.xlabel("Days into 2020")
plt.ylabel("Hours viewed per day")
plt.title("Did my viewer habits change over time?")
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import pymc3 as pm
import theano.tensor as tt

with pm.Model() as model:
    alpha = 1/dly_hrs_array.mean()  # Recall count_data is the
                                   # variable that holds our txt counts
    sigma_1 = pm.Exponential("sigma_1", alpha)
    sigma_2 = pm.Exponential("sigma_2", alpha)
    sigma_3 = pm.Exponential("sigma_3", alpha)

    
    tau_1 = pm.DiscreteUniform("tau_1", lower=0, upper=n_data_days - 1)
    tau_2 = pm.DiscreteUniform("tau_2",lower=tau_1,upper = n_data_days-1)
    idx = np.arange(n_data_days) # Index

    sigma_= pm.math.switch(tau_1 >= idx, sigma_1, sigma_2)
    sigma = pm.math.switch(tau_2 >= idx, sigma_, sigma_3)
  
    
    observation = pm.Exponential("obs",sigma, observed=dly_hrs_array)
    step = pm.Metropolis()
    trace = pm.sample(20000, tune=5000,step=step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [tau_2]
# >Metropolis: [tau_1]
# >Metropolis: [sigma_3]
# >Metropolis: [sigma_2]
# >Metropolis: [sigma_1]
# Sampling 2 chains, 0 divergences: 100%|██████████| 50000/50000 [00:39<00:00, 1263.63draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
sigma_1_samples = trace['sigma_1']
sigma_2_samples = trace['sigma_2']
sigma_3_samples = trace['sigma_3']

tau_1_samples = trace['tau_1']
tau_2_samples = trace['tau_2'] 
#histogram of the samples:

ax = plt.subplot(311)
ax.set_autoscaley_on(False)

plt.hist(sigma_1_samples, histtype='stepfilled', bins=30, alpha=0.85,
         label="posterior of $\lambda_1$", color="#A60628", density=True)
plt.legend(loc="upper left")
plt.title(r"""Posterior distributions of the variables
    $\lambda_1,\;\lambda_2,\;\tau$""")
plt.xlim([0.5, 2])
plt.ylim([0,5])
plt.xlabel("$\lambda_1$ value")

ax = plt.subplot(312)
ax.set_autoscaley_on(False)
plt.hist(sigma_2_samples, histtype='stepfilled', bins=30, alpha=0.85,
         label="posterior of $\lambda_2$", color="#7A68A6", density=True)
plt.legend(loc="upper left")
plt.ylim([0,.2])
plt.xlim([0, 25])
plt.xlabel("$\lambda_2$ value")


plt.subplot(313)
ax.set_autoscaley_on(False)
plt.hist(sigma_3_samples, histtype='stepfilled', bins=30, alpha=0.85,
         label="posterior of $\lambda_2$", color="#7A68A6", density=True)
plt.legend(loc="upper left")
plt.ylim([0,4])
plt.xlim([0.5, 1.5])
plt.xlabel("$\lambda_3$ value")

# plt.subplot(313)
# w = 1.0 / tau_1_samples.shape[0] * np.ones_like(tau_1_samples)
# plt.hist(tau_1_samples, bins=days, alpha=1,
#          label=r"posterior of $\tau$",
#          color="#467821", weights=w, rwidth=2.)
# plt.xticks(np.arange(days))

# plt.legend(loc="upper left")
# plt.ylim([0, .75])
# plt.xlim([0, 50])

# plt.xlabel(r"$\tau$ (in days)")
# plt.setp(w.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
# plt.ylabel("probability");
# Out:
# Text(0.5, 0, '$\\lambda_3$ value')

# %%
ax = plt.subplot(211)
ax.set_autoscaley_on(False)
plt.subplot(211)
w = 1.0 / tau_1_samples.shape[0] * np.ones_like(tau_1_samples)
plt.hist(tau_1_samples, bins=days, alpha=1,
         label=r"posterior of $\tau_1$",
         color="#467821", weights=w, rwidth=2.)
plt.xticks(np.arange(days))

plt.legend(loc="upper left")
plt.ylim([0, 1])
plt.xlim([80, 85])

plt.xlabel(r"$\tau_1$ (in days)")
plt.subplot(212)
v = 1.0 / tau_2_samples.shape[0] * np.ones_like(tau_2_samples)
plt.hist(tau_2_samples, bins=days, alpha=1,
         label=r"posterior of $\tau_2$",
         color="#467821", weights=w, rwidth=2.)
plt.xticks(np.arange(days))

plt.legend(loc="upper left")
plt.ylim([0, 1])
plt.xlim([100, 105])

plt.xlabel(r"$\tau_2$ (in days)")
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0.5, 0, '$\\tau_2$ (in days)')

# %%
def less_than_X(value,array,setpoint):
    count = 0
    for i in array : 
        if i > value : 
            count = count + 1
    pct_ = count/(len(array)+1)
    if pct_ >= setpoint:
        return True
    else:
        return False

def great_than_X(value,array,setpoint):
    count = 0
    for i in array : 
        if i < value : 
            count = count + 1
    pct_ = count/(len(array)+1)
    if pct_ >= setpoint:
        return True
    else:
        return False
    
# tau_samples, lambda_1_samples, lambda_2_samples contain
# N samples from the corresponding posterior distribution
N = tau_1_samples.shape[0]
expected_hrs_per_day = np.zeros(n_data_days)
for day in range(0, n_data_days):
    # ix is a bool index of all tau samples corresponding to
    # the switchpoint occurring prior to value of 'day'
    if (less_than_X(day,tau_1_samples,.8) and less_than_X(day,tau_2_samples,.8)):
#         print('one')
        ix = True
        expected_hrs_per_day[day] = (sigma_1_samples[ix].sum()+ sigma_2_samples[~ix].sum()+sigma_3_samples[~ix].sum()) / N
    elif (great_than_X(day,tau_1_samples,.8) and less_than_X(day,tau_2_samples,.8) ):
#         print('two')
        ix = True
        expected_hrs_per_day[day] = (sigma_1_samples[~ix].sum()+ sigma_2_samples[ix].sum()+sigma_3_samples[~ix].sum()) / N
    else:
#         print('three')
        ix = True
        expected_hrs_per_day[day] = (sigma_1_samples[~ix].sum()+ sigma_2_samples[~ix].sum()+sigma_3_samples[ix].sum()) / N

# %%
from matplotlib.patches import Ellipse
fig, ax = plt.subplots(figsize=(20,8))

el = Ellipse((2, -1), 0.5, 0.5)

days = ax.plot(np.arange(len(dly_hrs_array)),dly_hrs_array,color=Netflix_black,label='Observed hours per day',lw=4)
days = ax.plot(range(n_data_days), 1/expected_hrs_per_day, lw=4, color=Netflix_red,label="Expected number of hours*")
plt.vlines(77,0,6,label='March 17th: restaurants and bars close',linestyles='dashed',alpha=.6,lw=6)

plt.grid(axis='y')
plt.legend(loc='upper right')

plt.ylabel('Hours')
plt.ylim(0,6)
plt.xlabel('Day')
plt.xlim(0,195)

ax.annotate("Staying with my girlfriend",xy=(95, 0.5), xycoords='data',xytext=(50, 4.5), 
            textcoords='data',va="bottom", ha="right",
            arrowprops=dict(arrowstyle="simple", facecolor=Netflix_black, alpha=.6,
            connectionstyle="arc3,rad=-0.2",mutation_scale=25),verticalalignment='top',)


ann1 = ax.annotate('Pre-lockdown Exp.value: {:03.2f}hrs'.format(1/sigma_1_samples.mean()),xy=(45, .88), xycoords='data',
                  xytext=(15, 2.1), textcoords='data',
                  size=20, va="center",
                  bbox=dict(boxstyle="round", fc=Netflix_red, ec="none",alpha=.8),
                  arrowprops=dict(arrowstyle="wedge,tail_width=1.",alpha = .6,
                                  fc=Netflix_red, ec="none",
                                  patchA=None,
                                  patchB=el,
                                  relpos=(0.2, 0.5)))

ann2 = ax.annotate('Post-lockdown Exp.value: {:03.2f}hrs'.format(1/sigma_3_samples.mean()),xy=(144, 1.1), xycoords='data',
                  xytext=(119, 3.5), textcoords='data',
                  size=20, va="center",
                  bbox=dict(boxstyle="round", fc=Netflix_red, ec="none",alpha=.8),
                  arrowprops=dict(arrowstyle="wedge,tail_width=1.",alpha = .6,
                                  fc=Netflix_red, ec="none",
                                  patchA=None,
                                  patchB=el,
                                  relpos=(0.2, 0.5)))



plt.title('Viewing Behavior with COVID19')
plt.figtext(0.2, .01, "*PyMC3 used to generate expected hours", ha="center", fontsize=10)
plt.savefig('images/behavior_covid.png',dpi=500,bbox_inches='tight')
plt.show()
